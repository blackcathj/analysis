# %%
# imports to write dynamic markdown contents
import os
from IPython.display import display, Markdown, Latex
from IPython.display import HTML

import pandas as pd
from collections import OrderedDict

import pprint
import re
import numpy as np
import matplotlib.pyplot as plt
import random

import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
import plotly.express as px
init_notebook_mode(connected=True)  
import glob
import uproot 
import ROOT

import platform
print('Python:', platform.python_version())
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.16.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# Welcome to JupyROOT 6.26/06
# Python: 3.10.8

# %%
filename = "/phenix/u/jinhuang/links/sPHENIX_work/TPC/commissioning/TPC_ebdc11_beam-00011127-0000.prdf.TPCRawDataTree.root"
# filename = "/phenix/u/jinhuang/links/sPHENIX_work/TPC/commissioning/TPC_ebdc11_beam-00011129-0000.prdf.TPCRawDataTree.root"
file = ROOT.TFile.Open(filename)

file.ls()
file.PacketTree.Show(0)
file.SampleTree.Show(0)
file.TaggerTree.Show(0)
# Out:
# TFile**		/phenix/u/jinhuang/links/sPHENIX_work/TPC/commissioning/TPC_ebdc11_beam-00011127-0000.prdf.TPCRawDataTree.root
#  TFile*		/phenix/u/jinhuang/links/sPHENIX_work/TPC/commissioning/TPC_ebdc11_beam-00011127-0000.prdf.TPCRawDataTree.root
#   KEY: TTree	SampleTree;10	Each entry is one waveform [current cycle]
#   KEY: TTree	SampleTree;9	Each entry is one waveform [backup cycle]
#   KEY: TTree	PacketTree;1	Each entry is one packet
#   KEY: TTree	TaggerTree;1	Each entry is one tagger for level 1 trigger or endat tag
# ======> EVENT:0
#  packet          = 4110
#  frame           = 2
#  nWaveormInFrame = 934
#  nTaggerInFrame  = 2
#  maxFEECount     = 26
# ======> EVENT:0
#  packet          = 4110
#  frame           = 2
#  nWaveormInFrame = 934
#  maxFEECount     = 26
#  nSamples        = 360
#  adcSamples      = 60,
#                   64, 64, 66, 70, 60, 57, 64, 74, 70, 64,
#                   58, 71, 74, 64, 54, 60, 77, 74, 64
#  fee             = 25
#  sampaAddress    = 6
# ...

# %%
# %%cpp -d
#
# #include<sPhenixStyle.C>

# %%
# %%cpp
#
# SetsPhenixStyle()
# Out:
# sPhenixStyle: Applying nominal settings.
# sPhenixStyle: ROOT6 mode

# %%
# %jsroot on

# %%
c1 = ROOT.TCanvas( 'ADCQA', 'ADCQA', 1000, 400)

sector='11'
    
ROOT.gPad.SetLogz()
ROOT.gPad.SetLogy()

hADC = ROOT.TH2F(f'hADCZZ{sector}', f';Sector{sector}: ADC Time bin [1/20MHz]; ADC [ADU]', 360, 0, 360, 256, 0, 1024);
file.SampleTree.Draw(f"adcSamples - adcSamples[0]:Iteration$>>hADCZZ{sector}","checksumError==0 && (fee <= 1 || fee == 11 || fee == 12 | fee == 14 | fee == 15 | fee ==18 | fee == 19)","colz");

hADC.DrawClone("colz");

    
c1.Draw()
# Out:
# <div id="root_plot_1690517414440"
#      style="width: 996px; height: 372px">
# </div>
# <script>
#
# function display_root_plot_1690517414440(Core) {
# ...

# %%
c1 = ROOT.TCanvas( 'ADCQA', 'ADCQA', 1000, 400)

sector='06'
    
ROOT.gPad.SetLogz()
ROOT.gPad.SetLogy()

hADC = ROOT.TH2F(f'hADCZZFEE{sector}', f';Sector{sector}: FEE ID [0...25]; ADC [ADU]', 26, -.5, 25.5, 256, 0, 1024);
file.SampleTree.Draw(f"adcSamples - adcSamples[0]:fee>>hADCZZFEE{sector}","checksumError==0","colz");

hADC.DrawClone("colz");

    
c1.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: ADCQA
# <div id="root_plot_1690517442681"
#      style="width: 996px; height: 372px">
# </div>
# <script>
#
# function display_root_plot_1690517442681(Core) {
# ...

# %%
c1 = ROOT.TCanvas( 'ADCQA', 'ADCQA', 1000, 400)

sector='06'
    
ROOT.gPad.SetLogz()
ROOT.gPad.SetLogy()

hADC = ROOT.TH2F(f'hADCZZFEE{sector}', f';Sector{sector}: FEE ID [0...25]; ADC [ADU]', 26, -.5, 25.5, 256, 0, 1024);
file.SampleTree.Draw(f"adcSamples - adcSamples[0]:fee>>hADCZZFEE{sector}","checksumError==0 && (adcSamples - adcSamples[0])>27","colz");

hADC.DrawClone("colz");

    
c1.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: ADCQA
# Warning in <TFile::Append>: Replacing existing TH1: hADCZZFEE06 (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: hADCZZFEE06 (Potential memory leak).
# <div id="root_plot_1690517475740"
#      style="width: 996px; height: 372px">
# </div>
# <script>
#
# function display_root_plot_1690517475740(Core) {
# ...
